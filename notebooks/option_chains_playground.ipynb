# %%
from openbb import obb
import pandas as pd

# Get option chains for a specific stock for a specific date

def get_option_chains(symbol: str):
    """
    Get the latest option chains for a specific stock.

    Parameters:
    symbol (str): The stock symbol to get option chains for.

    """
    # Get the option chains for the specified stock and date
    option_chains = obb.derivatives.options.chains(symbol=symbol).to_dataframe()

    # Convert the result to a DataFrame
    

    return option_chains

# %%
test = get_option_chains('AAPL')

# %%
test
# Out:
#      underlying_symbol  underlying_price      contract_symbol  expiration  \
# 0                 AAPL          273.0598  AAPL260102P00110000  2026-01-02
# 1                 AAPL          273.0598  AAPL260102C00120000  2026-01-02
# 2                 AAPL          273.0598  AAPL260102P00120000  2026-01-02
# 3                 AAPL          273.0598  AAPL260102P00125000  2026-01-02
# 4                 AAPL          273.0598  AAPL260102P00130000  2026-01-02
# ...                ...               ...                  ...         ...
# 2209              AAPL          273.0598  AAPL280317C00510000  2028-03-17
# 2210              AAPL          273.0598  AAPL280317C00520000  2028-03-17
# 2211              AAPL          273.0598  AAPL280317C00530000  2028-03-17
# 2212              AAPL          273.0598  AAPL280317C00540000  2028-03-17
# 2213              AAPL          273.0598  AAPL280317C00550000  2028-03-17
#
#       dte  strike option_type  open_interest  volume  last_trade_price  \
# 0       6   110.0         put              1       1              0.01
# 1       6   120.0        call              1       1            151.73
# 2       6   120.0         put              2       1              0.03
# 3       6   125.0         put              1       1              0.01
# 4       6   130.0         put             69      69              0.02
# ...   ...     ...         ...            ...     ...               ...
# 2209  811   510.0        call             29       1              3.92
# 2210  811   520.0        call              4       1              3.23
# 2211  811   530.0        call             33      43              3.85
# 2212  811   540.0        call             29       2              2.68
# 2213  811   550.0        call            293      16              2.45
#
#                 last_trade_time     bid     ask  change  change_percent  \
# 0     2025-12-02 13:10:24-05:00    0.00    0.01    0.00        0.000000
# 1     2025-12-19 15:08:13-05:00  152.05  155.15    0.00        0.000000
# 2     2025-12-22 10:15:03-05:00    0.00    0.01    0.00        0.000000
# 3     2025-12-02 13:10:24-05:00    0.00    0.01    0.00        0.000000
# 4     2025-12-02 12:41:56-05:00    0.00    0.01    0.00        0.000000
# ...                         ...     ...     ...     ...             ...
# 2209  2025-12-18 15:45:13-05:00    3.45    3.80    0.00        0.000000
# 2210  2025-12-23 10:57:40-05:00    2.82    4.00    0.00        0.000000
# 2211  2025-12-08 15:10:14-05:00    2.78    3.10    0.00        0.000000
# 2212  2025-12-26 14:26:23-05:00    2.49    2.98   -0.03       -0.011070
# 2213  2025-12-26 14:50:08-05:00    2.35    2.75   -0.07       -0.027778
#
#       implied_volatility  in_the_money currency
# 0               1.937500         False      USD
# 1               2.533207          True      USD
# 2               1.781251         False      USD
# 3               1.687502         False      USD
# 4               1.625002         False      USD
# ...                  ...           ...      ...
# 2209            0.268593         False      USD
# 2210            0.277687         False      USD
# 2211            0.268806         False      USD
# 2212            0.272224         False      USD
# 2213            0.273323         False      USD
#
# [2214 rows x 18 columns]

# %%
test.columns
# Out:
# Index(['underlying_symbol', 'underlying_price', 'contract_symbol',
#        'expiration', 'dte', 'strike', 'option_type', 'open_interest', 'volume',
#        'last_trade_price', 'last_trade_time', 'bid', 'ask', 'change',
#        'change_percent', 'implied_volatility', 'in_the_money', 'currency'],
#       dtype='object')
