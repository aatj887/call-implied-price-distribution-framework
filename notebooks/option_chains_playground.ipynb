# %%
from openbb import obb
import pandas as pd

# Get option chains for a specific stock for a specific date

def get_option_chains(symbol: str, expiration_date: str) -> pd.DataFrame:
    """
    Get the latest option chains for a specific stock.

    Parameters:
    symbol (str): The stock symbol to get option chains for.
    expiration_date (str): The expiration date of the options in the format 'YYYY-MM-DD'.

    Returns:
    pd.DataFrame: A DataFrame containing the option chains for the specified stock and date.
    """
    # Get the option chains for the specified stock and date
    option_chains = obb.derivatives.options.chains(symbol=symbol).to_dataframe()

    # Convert the result to a DataFrame
    

    return option_chains

# %%
test = get_option_chains('AAPL', '2025-10-01')

# %%
test
# Out:
#      underlying_symbol  underlying_price      contract_symbol  expiration  \
# 0                 AAPL          270.7518  AAPL251226C00110000  2025-12-26
# 1                 AAPL          270.7518  AAPL251226C00120000  2025-12-26
# 2                 AAPL          270.7518  AAPL251226P00120000  2025-12-26
# 3                 AAPL          270.7518  AAPL251226C00125000  2025-12-26
# 4                 AAPL          270.7518  AAPL251226P00125000  2025-12-26
# ...                ...               ...                  ...         ...
# 2329              AAPL          270.7518  AAPL280317C00510000  2028-03-17
# 2330              AAPL          270.7518  AAPL280317C00520000  2028-03-17
# 2331              AAPL          270.7518  AAPL280317C00530000  2028-03-17
# 2332              AAPL          270.7518  AAPL280317C00540000  2028-03-17
# 2333              AAPL          270.7518  AAPL280317C00550000  2028-03-17
#
#       dte  strike option_type  open_interest  volume  last_trade_price  \
# 0       4   110.0        call              1       1            170.30
# 1       4   120.0        call              1       1            158.22
# 2       4   120.0         put              1       1              0.01
# 3       4   125.0        call              4       0            160.40
# 4       4   125.0         put              1       0              0.03
# ...   ...     ...         ...            ...     ...               ...
# 2329  816   510.0        call             29       1              3.92
# 2330  816   520.0        call              3       1              3.55
# 2331  816   530.0        call             33      43              3.85
# 2332  816   540.0        call             18      11              2.64
# 2333  816   550.0        call            214      42              2.37
#
#                 last_trade_time     bid     ask  change  change_percent  \
# 0     2025-12-05 13:39:45-05:00  159.70  162.10    0.00        0.000000
# 1     2025-12-08 10:37:49-05:00  149.70  152.10    0.00        0.000000
# 2     2025-12-19 13:09:39-05:00    0.00    0.01    0.00        0.000000
# 3     2025-12-03 14:20:43-05:00  144.65  147.10    0.00        0.000000
# 4     2025-12-15 11:09:11-05:00    0.00    0.01    0.00        0.000000
# ...                         ...     ...     ...     ...             ...
# 2329  2025-12-18 15:45:13-05:00    3.40    3.65    0.00        0.000000
# 2330  2025-12-18 10:58:51-05:00    3.05    3.30    0.00        0.000000
# 2331  2025-12-08 15:10:14-05:00    2.80    2.93    0.00        0.000000
# 2332  2025-12-18 15:19:22-05:00    2.47    2.65   -0.18       -0.063830
# 2333  2025-12-22 14:30:06-05:00    2.28    2.40   -0.05       -0.020661
#
#       implied_volatility  in_the_money currency
# 0               3.144533          True      USD
# 1               2.859378          True      USD
# 2               2.062505         False      USD
# 3               2.667972          True      USD
# 4               1.968750         False      USD
# ...                  ...           ...      ...
# 2329            0.269050         False      USD
# 2330            0.269233         False      USD
# 2331            0.268409         False      USD
# 2332            0.268593         False      USD
# 2333            0.268837         False      USD
#
# [2334 rows x 18 columns]
